# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 02'''

import openpyxl
import os

if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_02.xlsx'):
    print("Não há arquivo disponível para leitura")
else:
    # Faz a leitura da planilha base
    planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_02.xlsx')
    aba_base = planilha_base.active
    # Faz a leitura da planilha destino
    planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')
    
    # Acessa a aba específica "CITI 02"
    aba_destino = planilha_destino['CITI 02_90035620']
    
    ''' Parte do código que identifica a primeira linha vazia da planilha destino '''
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 1
    linha_destino = 1
    while aba_destino.cell(row=linha_destino, column=1).value is not None:
        linha_destino += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 2
    linha_destino_1 = 1
    while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
        linha_destino_1 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 3
    linha_destino_2 = 1
    while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
        linha_destino_2 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 4
    linha_destino_3 = 1
    while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
        linha_destino_3 += 1
    
    ''' Parte do código que encontra a linha do cabeçalho da planilha base '''
    
    # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
    linha_cabecalho = 1
    while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
        linha_cabecalho += 1
    
    # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
    linha_cabecalho_1 = 1
    while aba_base.cell(row=linha_cabecalho_1, column=6).value != "Descrição da Transação":
        linha_cabecalho_1 += 1
    
    # Encontrar a linha onde está o cabeçalho "Valor da Transação"
    linha_cabecalho_2 = 1
    while aba_base.cell(row=linha_cabecalho_2, column=9).value != "Valor da Transação":
        linha_cabecalho_2 += 1
    
    # Encontrar a linha onde está o cabeçalho "Débito"
    linha_cabecalho_3 = 1
    while aba_base.cell(row=linha_cabecalho_3, column=10).value != "Débito":
        linha_cabecalho_3 += 1
    
    ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''
    
    # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
    for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
        for valor in valor_celula:
            aba_destino.cell(row=linha_destino, column=1, value=valor)
            linha_destino += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 6ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
    for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=6, max_col=6, values_only=True), start=1):
        for valor in valor_celula_1:
            aba_destino.cell(row=linha_destino_1, column=2, value=valor)
            linha_destino_1 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
    for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
        for valor in valor_celula_2:
            aba_destino.cell(row=linha_destino_2, column=3, value=valor)
            linha_destino_2 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
    for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
        for valor in valor_celula_3:
            aba_destino.cell(row=linha_destino_3, column=4, value=valor)
            linha_destino_3 += 1
    
    # Salvar as alterações na planilha destino
    planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 03'''

import openpyxl
import os

if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_03.xlsx'):
    print("Não há arquivo disponível para leitura")
else:
    # Faz a leitura da planilha base
    planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_03.xlsx')
    aba_base = planilha_base.active
    # Faz a leitura da planilha destino
    planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')
    
    # Acessa a aba específica "CITI 03"
    aba_destino = planilha_destino['CITI 03_86390350']
    
    ''' Parte do código que identifica a primeira linha vazia da planilha destino '''
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 1
    linha_destino = 1
    while aba_destino.cell(row=linha_destino, column=1).value is not None:
        linha_destino += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 2
    linha_destino_1 = 1
    while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
        linha_destino_1 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 3
    linha_destino_2 = 1
    while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
        linha_destino_2 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 4
    linha_destino_3 = 1
    while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
        linha_destino_3 += 1
    
    ''' Parte do código que encontra a linha do cabeçalho da planilha base '''
    
    # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
    linha_cabecalho = 1
    while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
        linha_cabecalho += 1
    
    # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
    linha_cabecalho_1 = 1
    while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
        linha_cabecalho_1 += 1
    
    # Encontrar a linha onde está o cabeçalho "Valor da Transação"
    linha_cabecalho_2 = 1
    while aba_base.cell(row=linha_cabecalho_2, column=9).value != "Valor da Transação":
        linha_cabecalho_2 += 1
    
    # Encontrar a linha onde está o cabeçalho "Débito"
    linha_cabecalho_3 = 1
    while aba_base.cell(row=linha_cabecalho_3, column=10).value != "Débito":
        linha_cabecalho_3 += 1
    
    ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''
    
    # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
    for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
        for valor in valor_celula:
            aba_destino.cell(row=linha_destino, column=1, value=valor)
            linha_destino += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
    for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
        for valor in valor_celula_1:
            aba_destino.cell(row=linha_destino_1, column=2, value=valor)
            linha_destino_1 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
    for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
        for valor in valor_celula_2:
            aba_destino.cell(row=linha_destino_2, column=3, value=valor)
            linha_destino_2 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
    for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
        for valor in valor_celula_3:
            aba_destino.cell(row=linha_destino_3, column=4, value=valor)
            linha_destino_3 += 1
    
    # Salvar as alterações na planilha destino
    planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 04'''

import openpyxl
import os

if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_04.xlsx'):
    print("Não há arquivo disponível para leitura")
else:
    try:

        # Faz a leitura da planilha base
        planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_04.xlsx')
        aba_base = planilha_base.active

        # Faz a leitura da planilha destino
        planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


        # Acessa a aba específica "CITI 04"
        aba_destino = planilha_destino['CITI 04_86390384']

        ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

        # Encontrar a primeira linha vazia na planilha destino da coluna 1
        linha_destino = 1
        while aba_destino.cell(row=linha_destino, column=1).value is not None:
            linha_destino += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 2
        linha_destino_1 = 1
        while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
            linha_destino_1 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 3
        linha_destino_2 = 1
        while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
            linha_destino_2 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 4
        linha_destino_3 = 1
        while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
            linha_destino_3 += 1

        ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

        # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
        linha_cabecalho = 1
        while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
            linha_cabecalho += 1

        # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
        linha_cabecalho_1 = 1
        while aba_base.cell(row=linha_cabecalho_1, column=6).value != "Descrição da Transação":
            linha_cabecalho_1 += 1

        # Encontrar a linha onde está o cabeçalho "Valor da Transação"
        linha_cabecalho_2 = 1
        while aba_base.cell(row=linha_cabecalho_2, column=10).value != "Valor da Transação":
            linha_cabecalho_2 += 1

        # Encontrar a linha onde está o cabeçalho "Débito"
        linha_cabecalho_3 = 1
        while aba_base.cell(row=linha_cabecalho_3, column=11).value != "Débito":
            linha_cabecalho_3 += 1

        ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

        # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
        for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
            for valor in valor_celula:
                aba_destino.cell(row=linha_destino, column=1, value=valor)
                linha_destino += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 6ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
        for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=6, max_col=6, values_only=True), start=1):
            for valor in valor_celula_1:
                aba_destino.cell(row=linha_destino_1, column=2, value=valor)
                linha_destino_1 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
        for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
            for valor in valor_celula_2:
                aba_destino.cell(row=linha_destino_2, column=3, value=valor)
                linha_destino_2 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 11ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
        for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=11, max_col=11, values_only=True), start=1):
            for valor in valor_celula_3:
                aba_destino.cell(row=linha_destino_3, column=4, value=valor)
                linha_destino_3 += 1

        # Salvar as alterações na planilha destino
        planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')
    except:

        # Faz a leitura da planilha base
        planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_04.xlsx')
        aba_base = planilha_base.active

        # Faz a leitura da planilha destino
        planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


        # Acessa a aba específica "CITI 04"
        aba_destino = planilha_destino['CITI 04_86390384']

        ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

        # Encontrar a primeira linha vazia na planilha destino da coluna 1
        linha_destino = 1
        while aba_destino.cell(row=linha_destino, column=1).value is not None:
            linha_destino += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 2
        linha_destino_1 = 1
        while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
            linha_destino_1 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 3
        linha_destino_2 = 1
        while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
            linha_destino_2 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 4
        linha_destino_3 = 1
        while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
            linha_destino_3 += 1

        ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

        # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
        linha_cabecalho = 1
        while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
            linha_cabecalho += 1

        # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
        linha_cabecalho_1 = 1
        while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
            linha_cabecalho_1 += 1

        # Encontrar a linha onde está o cabeçalho "Valor da Transação"
        linha_cabecalho_2 = 1
        while aba_base.cell(row=linha_cabecalho_2, column=9).value != "Valor da Transação":
            linha_cabecalho_2 += 1

        # Encontrar a linha onde está o cabeçalho "Débito"
        linha_cabecalho_3 = 1
        while aba_base.cell(row=linha_cabecalho_3, column=10).value != "Débito":
            linha_cabecalho_3 += 1

        ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

        # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
        for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
            for valor in valor_celula:
                aba_destino.cell(row=linha_destino, column=1, value=valor)
                linha_destino += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 6ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
        for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
            for valor in valor_celula_1:
                aba_destino.cell(row=linha_destino_1, column=2, value=valor)
                linha_destino_1 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
        for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
            for valor in valor_celula_2:
                aba_destino.cell(row=linha_destino_2, column=3, value=valor)
                linha_destino_2 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 11ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
        for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
            for valor in valor_celula_3:
                aba_destino.cell(row=linha_destino_3, column=4, value=valor)
                linha_destino_3 += 1

        # Salvar as alterações na planilha destino
        planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 05'''

import openpyxl
import os


if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_05.xlsx'):
    print("Não há arquivo disponível para leitura")
else:

    # Faz a leitura da planilha base
    planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_05.xlsx')
    aba_base = planilha_base.active
    
    # Faz a leitura da planilha destino
    planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')
    
    
    # Acessa a aba específica "CITI 05"
    aba_destino = planilha_destino['CITI 05_90029578']
    
    ''' Parte do código que identifica a primeira linha vazia da planilha destino '''
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 1
    linha_destino = 1
    while aba_destino.cell(row=linha_destino, column=1).value is not None:
        linha_destino += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 2
    linha_destino_1 = 1
    while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
        linha_destino_1 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 3
    linha_destino_2 = 1
    while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
        linha_destino_2 += 1
    
    # Encontrar a primeira linha vazia na planilha destino da coluna 4
    linha_destino_3 = 1
    while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
        linha_destino_3 += 1
    
    ''' Parte do código que encontra a linha do cabeçalho da planilha base '''
    
    # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
    linha_cabecalho = 1
    while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
        linha_cabecalho += 1
    
    # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
    linha_cabecalho_1 = 1
    while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
        linha_cabecalho_1 += 1
    
    # Encontrar a linha onde está o cabeçalho "Valor da Transação"
    linha_cabecalho_2 = 1
    while aba_base.cell(row=linha_cabecalho_2, column=8).value != "Valor da Transação":
        linha_cabecalho_2 += 1
    
    # Encontrar a linha onde está o cabeçalho "Débito"
    linha_cabecalho_3 = 1
    while aba_base.cell(row=linha_cabecalho_3, column=9).value != "Débito":
        linha_cabecalho_3 += 1
    
    ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''
    
    # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
    for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
        for valor in valor_celula:
            aba_destino.cell(row=linha_destino, column=1, value=valor)
            linha_destino += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
    for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
        for valor in valor_celula_1:
            aba_destino.cell(row=linha_destino_1, column=2, value=valor)
            linha_destino_1 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 8ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
    for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=8, max_col=8, values_only=True), start=1):
        for valor in valor_celula_2:
            aba_destino.cell(row=linha_destino_2, column=3, value=valor)
            linha_destino_2 += 1
    
    # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
    for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
        for valor in valor_celula_3:
            aba_destino.cell(row=linha_destino_3, column=4, value=valor)
            linha_destino_3 += 1
    
    # Salvar as alterações na planilha destino
    planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 06'''

import openpyxl
import os


if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_06.xlsx'):
    print("Não há arquivo disponível para leitura")
else:

    # Faz a leitura da planilha base
    planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_06.xlsx')
    aba_base = planilha_base.active

    # Faz a leitura da planilha destino
    planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


    # Acessa a aba específica "CITI 06"
    aba_destino = planilha_destino['CITI 06_86390368']

    ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

    # Encontrar a primeira linha vazia na planilha destino da coluna 1
    linha_destino = 1
    while aba_destino.cell(row=linha_destino, column=1).value is not None:
        linha_destino += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 2
    linha_destino_1 = 1
    while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
        linha_destino_1 += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 3
    linha_destino_2 = 1
    while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
        linha_destino_2 += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 4
    linha_destino_3 = 1
    while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
        linha_destino_3 += 1

    ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

    # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
    linha_cabecalho = 1
    while aba_base.cell(row=linha_cabecalho, column=1).value != "Período de Data de Entrada":
        linha_cabecalho += 1

    # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
    linha_cabecalho_1 = 1
    while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
        linha_cabecalho_1 += 1

    # Encontrar a linha onde está o cabeçalho "Valor da Transação"
    linha_cabecalho_2 = 1
    while aba_base.cell(row=linha_cabecalho_2, column=7).value != "Valor da Transação":
        linha_cabecalho_2 += 1

    # Encontrar a linha onde está o cabeçalho "Débito"
    linha_cabecalho_3 = 1
    while aba_base.cell(row=linha_cabecalho_3, column=8).value != "Débito":
        linha_cabecalho_3 += 1

    ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

    # Iterar sobre as linhas abaixo do cabeçalho da 1ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
    for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=1, max_col=1, values_only=True), start=1):
        for valor in valor_celula:
            aba_destino.cell(row=linha_destino, column=1, value=valor)
            linha_destino += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
    for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
        for valor in valor_celula_1:
            aba_destino.cell(row=linha_destino_1, column=2, value=valor)
            linha_destino_1 += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 7ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
    for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=7, max_col=7, values_only=True), start=1):
        for valor in valor_celula_2:
            aba_destino.cell(row=linha_destino_2, column=3, value=valor)
            linha_destino_2 += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 8ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
    for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=8, max_col=8, values_only=True), start=1):
        for valor in valor_celula_3:
            aba_destino.cell(row=linha_destino_3, column=4, value=valor)
            linha_destino_3 += 1

    # Salvar as alterações na planilha destino
    planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 07'''

import openpyxl
import os


if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_07.xlsx'):
    print("Não há arquivo disponível para leitura")
else:

    try: 

        # Faz a leitura da planilha base
        planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_07.xlsx')
        aba_base = planilha_base.active

        # Faz a leitura da planilha destino
        planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


        # Acessa a aba específica "CITI 07"
        aba_destino = planilha_destino['CITI 07_86390406']

        ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

        # Encontrar a primeira linha vazia na planilha destino da coluna 1
        linha_destino = 1
        while aba_destino.cell(row=linha_destino, column=1).value is not None:
            linha_destino += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 2
        linha_destino_1 = 1
        while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
            linha_destino_1 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 3
        linha_destino_2 = 1
        while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
            linha_destino_2 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 4
        linha_destino_3 = 1
        while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
            linha_destino_3 += 1

        ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

        # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
        linha_cabecalho = 1
        while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
            linha_cabecalho += 1

        # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
        linha_cabecalho_1 = 1
        while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
            linha_cabecalho_1 += 1

        # Encontrar a linha onde está o cabeçalho "Valor da Transação"
        linha_cabecalho_2 = 1
        while aba_base.cell(row=linha_cabecalho_2, column=9).value != "Valor da Transação":
            linha_cabecalho_2 += 1

        # Encontrar a linha onde está o cabeçalho "Débito"
        linha_cabecalho_3 = 1
        while aba_base.cell(row=linha_cabecalho_3, column=10).value != "Débito":
            linha_cabecalho_3 += 1

        ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

        # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
        for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
            for valor in valor_celula:
                aba_destino.cell(row=linha_destino, column=1, value=valor)
                linha_destino += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
        for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
            for valor in valor_celula_1:
                aba_destino.cell(row=linha_destino_1, column=2, value=valor)
                linha_destino_1 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
        for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
            for valor in valor_celula_2:
                aba_destino.cell(row=linha_destino_2, column=3, value=valor)
                linha_destino_2 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
        for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
            for valor in valor_celula_3:
                aba_destino.cell(row=linha_destino_3, column=4, value=valor)
                linha_destino_3 += 1

        # Salvar as alterações na planilha destino
        planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')
    except:
        # Faz a leitura da planilha base
        planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_07.xlsx')
        aba_base = planilha_base.active

        # Faz a leitura da planilha destino
        planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


        # Acessa a aba específica "CITI 07"
        aba_destino = planilha_destino['CITI 07_86390406']

        ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

        # Encontrar a primeira linha vazia na planilha destino da coluna 1
        linha_destino = 1
        while aba_destino.cell(row=linha_destino, column=1).value is not None:
            linha_destino += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 2
        linha_destino_1 = 1
        while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
            linha_destino_1 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 3
        linha_destino_2 = 1
        while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
            linha_destino_2 += 1

        # Encontrar a primeira linha vazia na planilha destino da coluna 4
        linha_destino_3 = 1
        while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
            linha_destino_3 += 1

        ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

        # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
        linha_cabecalho = 1
        while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
            linha_cabecalho += 1

        # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
        linha_cabecalho_1 = 1
        while aba_base.cell(row=linha_cabecalho_1, column=6).value != "Descrição da Transação":
            linha_cabecalho_1 += 1

        # Encontrar a linha onde está o cabeçalho "Valor da Transação"
        linha_cabecalho_2 = 1
        while aba_base.cell(row=linha_cabecalho_2, column=10).value != "Valor da Transação":
            linha_cabecalho_2 += 1

        # Encontrar a linha onde está o cabeçalho "Débito"
        linha_cabecalho_3 = 1
        while aba_base.cell(row=linha_cabecalho_3, column=11).value != "Débito":
            linha_cabecalho_3 += 1

        ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

        # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
        for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
            for valor in valor_celula:
                aba_destino.cell(row=linha_destino, column=1, value=valor)
                linha_destino += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
        for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=6, max_col=6, values_only=True), start=1):
            for valor in valor_celula_1:
                aba_destino.cell(row=linha_destino_1, column=2, value=valor)
                linha_destino_1 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
        for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=10, max_col=10, values_only=True), start=1):
            for valor in valor_celula_2:
                aba_destino.cell(row=linha_destino_2, column=3, value=valor)
                linha_destino_2 += 1

        # Iterar sobre as linhas abaixo do cabeçalho da 10ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
        for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=11, max_col=11, values_only=True), start=1):
            for valor in valor_celula_3:
                aba_destino.cell(row=linha_destino_3, column=4, value=valor)
                linha_destino_3 += 1

        # Salvar as alterações na planilha destino
        planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')

# %%
''' PLANILHA DE SALDO APLICADO -> ABA CITI 10'''

import openpyxl
import os


if not os.path.exists(r'C:\Users\U003659\Desktop\Extrato_citi_10.xlsx'):
    print("Não há arquivo disponível para leitura")
else:

    # Faz a leitura da planilha base
    planilha_base = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Extrato_citi_10.xlsx')
    aba_base = planilha_base.active

    # Faz a leitura da planilha destino
    planilha_destino = openpyxl.load_workbook(r'C:\Users\U003659\Desktop\Conferência_2024_Escrows_Citi.xlsx')


    # Acessa a aba específica "CITI 10"
    aba_destino = planilha_destino['CITI 10_86390376']

    ''' Parte do código que identifica a primeira linha vazia da planilha destino '''

    # Encontrar a primeira linha vazia na planilha destino da coluna 1
    linha_destino = 1
    while aba_destino.cell(row=linha_destino, column=1).value is not None:
        linha_destino += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 2
    linha_destino_1 = 1
    while aba_destino.cell(row=linha_destino_1, column=2).value is not None:
        linha_destino_1 += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 3
    linha_destino_2 = 1
    while aba_destino.cell(row=linha_destino_2, column=3).value is not None:
        linha_destino_2 += 1

    # Encontrar a primeira linha vazia na planilha destino da coluna 4
    linha_destino_3 = 1
    while aba_destino.cell(row=linha_destino_3, column=4).value is not None:
        linha_destino_3 += 1

    ''' Parte do código que encontra a linha do cabeçalho da planilha base '''

    # Encontrar a linha onde está o cabeçalho "Período de Data de Data"
    linha_cabecalho = 1
    while aba_base.cell(row=linha_cabecalho, column=2).value != "Período de Data de Data":
        linha_cabecalho += 1

    # Encontrar a linha onde está o cabeçalho "Descrição da Transação"
    linha_cabecalho_1 = 1
    while aba_base.cell(row=linha_cabecalho_1, column=5).value != "Descrição da Transação":
        linha_cabecalho_1 += 1

    # Encontrar a linha onde está o cabeçalho "Valor da Transação"
    linha_cabecalho_2 = 1
    while aba_base.cell(row=linha_cabecalho_2, column=8).value != "Valor da Transação":
        linha_cabecalho_2 += 1

    # Encontrar a linha onde está o cabeçalho "Débito"
    linha_cabecalho_3 = 1
    while aba_base.cell(row=linha_cabecalho_3, column=9).value != "Débito":
        linha_cabecalho_3 += 1

    ''' Parte do código que pega as informações da planilha base e copia para a planilha destino '''

    # Iterar sobre as linhas abaixo do cabeçalho da 2ª coluna da planilha base e copiar para a 1ª coluna da planilha destino
    for linha, valor_celula in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=2, max_col=2, values_only=True), start=1):
        for valor in valor_celula:
            aba_destino.cell(row=linha_destino, column=1, value=valor)
            linha_destino += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 5ª coluna da planilha base e copiar para a 2ª coluna da planilha destino
    for linha_1, valor_celula_1 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=5, max_col=5, values_only=True), start=1):
        for valor in valor_celula_1:
            aba_destino.cell(row=linha_destino_1, column=2, value=valor)
            linha_destino_1 += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 8ª coluna da planilha base e copiar para a 3ª coluna da planilha destino
    for linha_2, valor_celula_2 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=8, max_col=8, values_only=True), start=1):
        for valor in valor_celula_2:
            aba_destino.cell(row=linha_destino_2, column=3, value=valor)
            linha_destino_2 += 1

    # Iterar sobre as linhas abaixo do cabeçalho da 9ª coluna da planilha base e copiar para a 4ª coluna da planilha destino
    for linha_3, valor_celula_3 in enumerate(aba_base.iter_rows(min_row=linha_cabecalho + 1, min_col=9, max_col=9, values_only=True), start=1):
        for valor in valor_celula_3:
            aba_destino.cell(row=linha_destino_3, column=4, value=valor)
            linha_destino_3 += 1

    # Salvar as alterações na planilha destino
    planilha_destino.save('Conferência_2024_Escrows_Citi.xlsx')
